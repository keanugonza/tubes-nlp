# %%
import json
import re

# %%
INPUT_PATH = "text_all_merged.json"
OUTPUT_PATH = "text_all_merged_cleaned.json"

# %%
def clean_text(text):
    text = re.sub(r"<br\s*/?>", " ", text, flags=re.IGNORECASE)
    text = re.sub(r"<.*?>", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text


def clean_json_file(input_path, output_path):
    with open(input_path, "r", encoding="utf-8") as f:
        data = json.load(f)
    cleaned_reviews = []
    for item in data["reviews"]:
        cleaned_reviews.append({
            "id": item["id"],
            "text": clean_text(item["text"])
        })
    cleaned_data = {
        "dataset": data.get("dataset", ""),
        "description": data.get("description", ""),
        "total_reviews": len(cleaned_reviews),
        "reviews": cleaned_reviews
    }
    with open(output_path, "w", encoding="utf-8") as f:
        json.dump(cleaned_data, f, indent=2, ensure_ascii=False)

    print(f"Saved cleaned file to: {output_path}")

# %%
clean_json_file(INPUT_PATH, OUTPUT_PATH)
# Out:
# Saved cleaned file to: text_all_merged_cleaned.json
