# %%
import json
import torch
import joblib
import pandas as pd
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification

# %%
SAVED_MODEL_NER = "../model/NER/deberta_ner_saved"
SAVED_MODEL_ABSA = "../model/absa/deberta_absa_saved"
SAVED_MODEL_EMOTION = "../model/emotion/saved_classical_model"
ABSA_CSV_PATH = "absa_flat.csv"
TEST_TEXT_PATH = "../data/test_text.json"
OUTPUT_JSON_PATH = "predictions.json"
MAX_LENGTH = 256
FIXED_ASPECTS = [
    "acting",
    "plot",
    "characters",
    "cinematography",
    "script",
    "music",
    "ending",
]
EMOTION_LABELS = ["disgust", "anger", "sadness", "joy", "neutral", "fear", "surprise"]

# %%
ner_pipeline = pipeline(
    "token-classification",
    model=SAVED_MODEL_NER,
    tokenizer=SAVED_MODEL_NER,
    aggregation_strategy="simple"
)
# Out:
# Device set to use cuda:0

# %%
absa_tokenizer = AutoTokenizer.from_pretrained(SAVED_MODEL_ABSA)
absa_model = AutoModelForSequenceClassification.from_pretrained(SAVED_MODEL_ABSA)
absa_model.eval()
# Out:
# DebertaV2ForSequenceClassification(
#   (deberta): DebertaV2Model(
#     (embeddings): DebertaV2Embeddings(
#       (word_embeddings): Embedding(128100, 768, padding_idx=0)
#       (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): DebertaV2Encoder(
#       (layer): ModuleList(
#         (0-11): 12 x DebertaV2Layer(
#           (attention): DebertaV2Attention(
#             (self): DisentangledSelfAttention(
#               (query_proj): Linear(in_features=768, out_features=768, bias=True)
#               (key_proj): Linear(in_features=768, out_features=768, bias=True)
#               (value_proj): Linear(in_features=768, out_features=768, bias=True)
#               (pos_dropout): Dropout(p=0.1, inplace=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): DebertaV2SelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): DebertaV2Intermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): DebertaV2Output(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (rel_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#     )
#   )
#   (pooler): ContextPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0, inplace=False)
#   )
#   (classifier): Linear(in_features=768, out_features=3, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )

# %%
emotion_model_path = f"{SAVED_MODEL_EMOTION}/classical_model.pkl"
emotion_model = joblib.load(emotion_model_path)
print("Emotion model (SVM) loaded successfully.")
# Out:
# Emotion model (SVM) loaded successfully.

# %%
def build_id2fixed_aspects(csv_path):
    df = pd.read_csv(csv_path)
    allowed = {a.lower() for a in FIXED_ASPECTS}
    id2aspects = {}

    grouped = df.groupby("id")
    for review_id, group in grouped:
        aspek_list = []
        seen = set()
        for asp in group["aspect"]:
            asp_lower = str(asp).lower()
            if asp_lower in allowed and asp_lower not in seen:
                aspek_list.append(asp)
                seen.add(asp_lower)
        id2aspects[review_id] = aspek_list

    return id2aspects

ID2FIXED_ASPECTS = build_id2fixed_aspects(ABSA_CSV_PATH)

def load_test_data(text_file):
    with open(text_file, "r", encoding="utf-8") as f:
        data = json.load(f)
    return {item["id"]: item["text"] for item in data["reviews"]}

# ================== EMOTION CLASSIFICATION ==================

def predict_emotion(text):
    """Predicts emotion label using the SVM model."""
    pred_id = emotion_model.predict([text])[0]
    return EMOTION_LABELS[pred_id]

# ================== NER + ABSA ==================

def extract_actors(ner_results):
    actors = [
        ent["word"]
        for ent in ner_results
        if ent["entity_group"].upper() == "ACTOR"
    ]
    seen = set()
    uniq = []
    for a in actors:
        if a not in seen:
            uniq.append(a)
            seen.add(a)
    return uniq

def extract_fixed_aspects(review_id):
    return ID2FIXED_ASPECTS.get(review_id, [])

def predict_absa(text, aspect):
    encoded = absa_tokenizer(
        aspect,
        text,
        truncation=True,
        padding="max_length",
        max_length=MAX_LENGTH,
        return_tensors="pt"
    )

    with torch.no_grad():
        output = absa_model(**encoded)
        pred_id = torch.argmax(output.logits, dim=-1).item()

    return absa_model.config.id2label[pred_id]

def normalize_ner_results(ner_results):
    """Convert seluruh nilai hasil NER ke tipe Python native."""
    normalized = []
    for ent in ner_results:
        new_ent = {}
        for k, v in ent.items():
            # convert numpy types → python native
            if hasattr(v, "item"):
                v = v.item()
            new_ent[k] = v
        normalized.append(new_ent)
    return normalized

def run_ner_absa(review_id, text):
    ner_results = ner_pipeline(text)
    ner_results = normalize_ner_results(ner_results)

    actors = extract_actors(ner_results)
    fixed_aspects = extract_fixed_aspects(review_id)
    all_aspects = actors + fixed_aspects

    absa_outputs = [
        {
            "aspect": aspect,
            "sentiment": predict_absa(text, aspect)
        }
        for aspect in all_aspects
    ]

    emotion_label = predict_emotion(text)

    return {
        "id": review_id,
        "text": text,
        "emotion": emotion_label,
        "ner_results": ner_results,
        "actors": actors,
        "fixed_aspects": fixed_aspects,
        "absa_predictions": absa_outputs,
    }

# %%
if __name__ == "__main__":
    test_texts = load_test_data(TEST_TEXT_PATH)

    all_outputs_for_json = []

    print("===== Combined NER + ABSA + Emotion (Test Set) =====\n")

    for review_id, text in test_texts.items():
        result = run_ner_absa(review_id, text)
        clean_result = {
            "id": result["id"],
            "emotion": result["emotion"],
            "ner_results": result["ner_results"],
            "actors": result["actors"],
            "fixed_aspects": result["fixed_aspects"],
            "absa_predictions": result["absa_predictions"],
        }

        print(f"ID: {review_id}")
        print(json.dumps(clean_result, indent=2, ensure_ascii=False))
        print("-" * 60)

        all_outputs_for_json.append(clean_result)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# ===== Combined NER + ABSA + Emotion (Test Set) =====
# ID: pos_601
# {
#   "id": "pos_601",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9911526441574097,
#       "word": "Michael Pollard",
#       "start": 279,
#       "end": 295
#     }
#   ],
#   "actors": [
#     "Michael Pollard"
#   ],
#   "fixed_aspects": [
#     "plot",
#     "cinematography",
#     "acting"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "Michael Pollard",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "plot",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "cinematography",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "acting",
#       "sentiment": "positive"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: pos_602
# {
#   "id": "pos_602",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.9122870564460754,
#       "word": "Carlos Saura",
#       "start": 237,
#       "end": 250
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.6527535319328308,
#       "word": "Iberia",
#       "start": 405,
#       "end": 412
#     }
#   ],
#   "actors": [],
#   "fixed_aspects": [
#     "cinematography",
#     "music",
#     "ending"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "cinematography",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "music",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "ending",
#       "sentiment": "negative"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: pos_602
# {
#   "id": "pos_602",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.9122870564460754,
#       "word": "Carlos Saura",
#       "start": 237,
#       "end": 250
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.6527535319328308,
#       "word": "Iberia",
#       "start": 405,
#       "end": 412
#     }
#   ],
#   "actors": [],
#   "fixed_aspects": [
#     "cinematography",
#     "music",
#     "ending"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "cinematography",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "music",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "ending",
#       "sentiment": "negative"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: pos_603
# {
#   "id": "pos_603",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.1776612550020218,
#       "word": "",
#       "start": 438,
#       "end": 439
#     },
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.6910669803619385,
#       "word": "Saura",
#       "start": 1047,
#       "end": 1053
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.4572337567806244,
#       "word": "\"",
#       "start": 1145,
#       "end": 1147
#     }
#   ],
#   "actors": [],
#   "fixed_aspects": [
#     "music",
#     "plot",
#     "ending"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "music",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "plot",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "ending",
#       "sentiment": "positive"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: pos_603
# {
#   "id": "pos_603",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.1776612550020218,
#       "word": "",
#       "start": 438,
#       "end": 439
#     },
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.6910669803619385,
#       "word": "Saura",
#       "start": 1047,
#       "end": 1053
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.4572337567806244,
#       "word": "\"",
#       "start": 1145,
#       "end": 1147
#     }
#   ],
#   "actors": [],
#   "fixed_aspects": [
#     "music",
#     "plot",
#     "ending"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "music",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "plot",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "ending",
#       "sentiment": "positive"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: pos_604
# {
#   "id": "pos_604",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.9121560454368591,
#       "word": "Carlos Saura",
#       "start": 141,
#       "end": 154
#     }
#   ],
#   "actors": [],
#   "fixed_aspects": [
#     "cinematography",
#     "music"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "cinematography",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "music",
#       "sentiment": "positive"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: pos_604
# {
#   "id": "pos_604",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.9121560454368591,
#       "word": "Carlos Saura",
#       "start": 141,
#       "end": 154
#     }
#   ],
#   "actors": [],
#   "fixed_aspects": [
#     "cinematography",
#     "music"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "cinematography",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "music",
#       "sentiment": "positive"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: pos_605
# {
#   "id": "pos_605",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "MOVIE",
#       "score": 0.7360087037086487,
#       "word": "Amore Brujo",
#       "start": 409,
#       "end": 421
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.4778454303741455,
#       "word": "mé",
#       "start": 453,
#       "end": 455
#     },
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.4447879493236542,
#       "word": "Isaac",
#       "start": 661,
#       "end": 667
#     },
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.6599881052970886,
#       "word": "Antonio Gades",
#       "start": 2318,
#       "end": 2332
#     },
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.52204829454422,
#       "word": "Storaro",
#       "start": 2576,
#       "end": 2584
#     }
#   ],
#   "actors": [],
#   "fixed_aspects": [
#     "music",
#     "cinematography",
#     "plot"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "music",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "cinematography",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "plot",
#       "sentiment": "positive"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: pos_605
# {
#   "id": "pos_605",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "MOVIE",
#       "score": 0.7360087037086487,
#       "word": "Amore Brujo",
#       "start": 409,
#       "end": 421
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.4778454303741455,
#       "word": "mé",
#       "start": 453,
#       "end": 455
#     },
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.4447879493236542,
#       "word": "Isaac",
#       "start": 661,
#       "end": 667
#     },
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.6599881052970886,
#       "word": "Antonio Gades",
#       "start": 2318,
#       "end": 2332
#     },
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.52204829454422,
#       "word": "Storaro",
#       "start": 2576,
#       "end": 2584
#     }
#   ],
#   "actors": [],
#   "fixed_aspects": [
#     "music",
#     "cinematography",
#     "plot"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "music",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "cinematography",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "plot",
#       "sentiment": "positive"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: pos_606
# {
#   "id": "pos_606",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.8268913626670837,
#       "word": "Saura",
#       "start": 20,
#       "end": 26
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9599831104278564,
#       "word": "Ibéria",
#       "start": 130,
#       "end": 137
#     }
#   ],
#   "actors": [],
#   "fixed_aspects": [
#     "music",
#     "cinematography"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "music",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "cinematography",
#       "sentiment": "positive"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: pos_606
# {
#   "id": "pos_606",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.8268913626670837,
#       "word": "Saura",
#       "start": 20,
#       "end": 26
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9599831104278564,
#       "word": "Ibéria",
#       "start": 130,
#       "end": 137
#     }
#   ],
#   "actors": [],
#   "fixed_aspects": [
#     "music",
#     "cinematography"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "music",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "cinematography",
#       "sentiment": "positive"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: pos_607
# {
#   "id": "pos_607",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9793499112129211,
#       "word": "De Niro",
#       "start": 252,
#       "end": 260
#     }
#   ],
#   "actors": [
#     "De Niro"
#   ],
#   "fixed_aspects": [
#     "script",
#     "acting",
#     "cinematography"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "De Niro",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "script",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "acting",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "cinematography",
#       "sentiment": "positive"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: pos_607
# {
#   "id": "pos_607",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9793499112129211,
#       "word": "De Niro",
#       "start": 252,
#       "end": 260
#     }
#   ],
#   "actors": [
#     "De Niro"
#   ],
#   "fixed_aspects": [
#     "script",
#     "acting",
#     "cinematography"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "De Niro",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "script",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "acting",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "cinematography",
#       "sentiment": "positive"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: pos_608
# {
#   "id": "pos_608",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "GENRE",
#       "score": 0.5403560400009155,
#       "word": "fantasy",
#       "start": 58,
#       "end": 66
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9916650056838989,
#       "word": "Claire Danes",
#       "start": 285,
#       "end": 298
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9912000298500061,
#       "word": "Michelle Pfeiffer",
#       "start": 415,
#       "end": 433
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9869497418403625,
#       "word": "Robert De Niro",
#       "start": 519,
#       "end": 534
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9535681009292603,
#       "word": "Stardust",
#       "start": 836,
#       "end": 845
#     }
#   ],
#   "actors": [
#     "Claire Danes",
#     "Michelle Pfeiffer",
#     "Robert De Niro"
#   ],
#   "fixed_aspects": [
#     "plot",
#     "script",
#     "cinematography"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "Claire Danes",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Michelle Pfeiffer",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Robert De Niro",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "plot",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "script",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "cinematography",
#       "sentiment": "positive"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: pos_608
# {
#   "id": "pos_608",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "GENRE",
#       "score": 0.5403560400009155,
#       "word": "fantasy",
#       "start": 58,
#       "end": 66
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9916650056838989,
#       "word": "Claire Danes",
#       "start": 285,
#       "end": 298
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9912000298500061,
#       "word": "Michelle Pfeiffer",
#       "start": 415,
#       "end": 433
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9869497418403625,
#       "word": "Robert De Niro",
#       "start": 519,
#       "end": 534
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9535681009292603,
#       "word": "Stardust",
#       "start": 836,
#       "end": 845
#     }
#   ],
#   "actors": [
#     "Claire Danes",
#     "Michelle Pfeiffer",
#     "Robert De Niro"
#   ],
#   "fixed_aspects": [
#     "plot",
#     "script",
#     "cinematography"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "Claire Danes",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Michelle Pfeiffer",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Robert De Niro",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "plot",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "script",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "cinematography",
#       "sentiment": "positive"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: pos_609
# {
#   "id": "pos_609",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "GENRE",
#       "score": 0.4932567775249481,
#       "word": "fairytale",
#       "start": 46,
#       "end": 56
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9429259896278381,
#       "word": "Stardust",
#       "start": 77,
#       "end": 86
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9940502643585205,
#       "word": "Claire Danes",
#       "start": 723,
#       "end": 736
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9912841320037842,
#       "word": "Michelle Pfeiffer",
#       "start": 792,
#       "end": 810
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9898690581321716,
#       "word": "Robert Deniro",
#       "start": 896,
#       "end": 910
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9928708076477051,
#       "word": "Charlie Cox",
#       "start": 956,
#       "end": 968
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.9756435751914978,
#       "word": "Tristan",
#       "start": 980,
#       "end": 988
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9917376041412354,
#       "word": "Mark Strong",
#       "start": 1163,
#       "end": 1175
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.8954538106918335,
#       "word": "Jason Flemyng",
#       "start": 1176,
#       "end": 1190
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9776973724365234,
#       "word": "Ruppert Everett",
#       "start": 1195,
#       "end": 1211
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9929234385490417,
#       "word": "Peter O",
#       "start": 1291,
#       "end": 1299
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9383166432380676,
#       "word": "Toole",
#       "start": 1300,
#       "end": 1305
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9515429735183716,
#       "word": "Ricky Gervais",
#       "start": 1358,
#       "end": 1372
#     }
#   ],
#   "actors": [
#     "Claire Danes",
#     "Michelle Pfeiffer",
#     "Robert Deniro",
#     "Charlie Cox",
#     "Mark Strong",
#     "Jason Flemyng",
#     "Ruppert Everett",
#     "Peter O",
#     "Toole",
#     "Ricky Gervais"
#   ],
#   "fixed_aspects": [
#     "plot",
#     "acting",
#     "cinematography",
#     "script"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "Claire Danes",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Michelle Pfeiffer",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Robert Deniro",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Charlie Cox",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Mark Strong",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Jason Flemyng",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Ruppert Everett",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Peter O",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Toole",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Ricky Gervais",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "plot",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "acting",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "cinematography",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "script",
#       "sentiment": "positive"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: pos_609
# {
#   "id": "pos_609",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "GENRE",
#       "score": 0.4932567775249481,
#       "word": "fairytale",
#       "start": 46,
#       "end": 56
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9429259896278381,
#       "word": "Stardust",
#       "start": 77,
#       "end": 86
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9940502643585205,
#       "word": "Claire Danes",
#       "start": 723,
#       "end": 736
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9912841320037842,
#       "word": "Michelle Pfeiffer",
#       "start": 792,
#       "end": 810
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9898690581321716,
#       "word": "Robert Deniro",
#       "start": 896,
#       "end": 910
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9928708076477051,
#       "word": "Charlie Cox",
#       "start": 956,
#       "end": 968
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.9756435751914978,
#       "word": "Tristan",
#       "start": 980,
#       "end": 988
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9917376041412354,
#       "word": "Mark Strong",
#       "start": 1163,
#       "end": 1175
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.8954538106918335,
#       "word": "Jason Flemyng",
#       "start": 1176,
#       "end": 1190
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9776973724365234,
#       "word": "Ruppert Everett",
#       "start": 1195,
#       "end": 1211
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9929234385490417,
#       "word": "Peter O",
#       "start": 1291,
#       "end": 1299
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9383166432380676,
#       "word": "Toole",
#       "start": 1300,
#       "end": 1305
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9515429735183716,
#       "word": "Ricky Gervais",
#       "start": 1358,
#       "end": 1372
#     }
#   ],
#   "actors": [
#     "Claire Danes",
#     "Michelle Pfeiffer",
#     "Robert Deniro",
#     "Charlie Cox",
#     "Mark Strong",
#     "Jason Flemyng",
#     "Ruppert Everett",
#     "Peter O",
#     "Toole",
#     "Ricky Gervais"
#   ],
#   "fixed_aspects": [
#     "plot",
#     "acting",
#     "cinematography",
#     "script"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "Claire Danes",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Michelle Pfeiffer",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Robert Deniro",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Charlie Cox",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Mark Strong",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Jason Flemyng",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Ruppert Everett",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Peter O",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Toole",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Ricky Gervais",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "plot",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "acting",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "cinematography",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "script",
#       "sentiment": "positive"
#     }
#   ]
# }
# ------------------------------------------------------------
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# ID: pos_610
# {
#   "id": "pos_610",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9331985712051392,
#       "word": "Stardust",
#       "start": 8,
#       "end": 17
#     },
#     {
#       "entity_group": "GENRE",
#       "score": 0.6543613076210022,
#       "word": "fantasy",
#       "start": 31,
#       "end": 39
#     },
#     {
#       "entity_group": "GENRE",
#       "score": 0.5082765221595764,
#       "word": "fairytale",
#       "start": 229,
#       "end": 239
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.8940114378929138,
#       "word": "Yvaine",
#       "start": 684,
#       "end": 691
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.9717828035354614,
#       "word": "Victoria",
#       "start": 699,
#       "end": 708
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9935416579246521,
#       "word": "Claire Danes",
#       "start": 793,
#       "end": 806
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9171909093856812,
#       "word": "Cox",
#       "start": 923,
#       "end": 927
#     }
#   ],
#   "actors": [
#     "Claire Danes",
#     "Cox"
#   ],
#   "fixed_aspects": [
#     "ending",
#     "acting",
#     "plot",
#     "cinematography"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "Claire Danes",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Cox",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "ending",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "acting",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "plot",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "cinematography",
#       "sentiment": "positive"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: pos_611
# {
#   "id": "pos_611",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9858323335647583,
#       "word": "Rush Hour",
#       "start": 338,
#       "end": 347
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9813665151596069,
#       "word": "The Bourn Ultimatum",
#       "start": 402,
#       "end": 421
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.98004549741745,
#       "word": "The Simpsons Movie",
#       "start": 528,
#       "end": 546
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9850994348526001,
#       "word": "Stardust",
#       "start": 653,
#       "end": 661
#     }
#   ],
#   "actors": [],
#   "fixed_aspects": [],
#   "absa_predictions": []
# }
# ------------------------------------------------------------
# ID: pos_612
# {
#   "id": "pos_612",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9805203080177307,
#       "word": "\"Princess Bride",
#       "start": 89,
#       "end": 105
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.8890681862831116,
#       "word": "\"Stardust",
#       "start": 224,
#       "end": 234
#     },
#     {
#       "entity_group": "GENRE",
#       "score": 0.5389789938926697,
#       "word": "fantasy",
#       "start": 271,
#       "end": 279
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9884607195854187,
#       "word": "\"Return of the King",
#       "start": 1231,
#       "end": 1251
#     }
#   ],
#   "actors": [],
#   "fixed_aspects": [
#     "plot",
#     "script",
#     "acting",
#     "cinematography",
#     "music"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "plot",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "script",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "acting",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "cinematography",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "music",
#       "sentiment": "positive"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: pos_612
# {
#   "id": "pos_612",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9805203080177307,
#       "word": "\"Princess Bride",
#       "start": 89,
#       "end": 105
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.8890681862831116,
#       "word": "\"Stardust",
#       "start": 224,
#       "end": 234
#     },
#     {
#       "entity_group": "GENRE",
#       "score": 0.5389789938926697,
#       "word": "fantasy",
#       "start": 271,
#       "end": 279
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9884607195854187,
#       "word": "\"Return of the King",
#       "start": 1231,
#       "end": 1251
#     }
#   ],
#   "actors": [],
#   "fixed_aspects": [
#     "plot",
#     "script",
#     "acting",
#     "cinematography",
#     "music"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "plot",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "script",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "acting",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "cinematography",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "music",
#       "sentiment": "positive"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: pos_613
# {
#   "id": "pos_613",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "GENRE",
#       "score": 0.5778058767318726,
#       "word": "fantasy",
#       "start": 214,
#       "end": 222
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9854376316070557,
#       "word": "StarDust",
#       "start": 386,
#       "end": 395
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.989562451839447,
#       "word": "Robert De Niro",
#       "start": 601,
#       "end": 616
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.990917444229126,
#       "word": "Michelle Pfeiffer",
#       "start": 712,
#       "end": 730
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9894522428512573,
#       "word": "Claire Danes",
#       "start": 756,
#       "end": 769
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.8781657218933105,
#       "word": "Yvaine",
#       "start": 824,
#       "end": 831
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.9544599652290344,
#       "word": "Captain Shakespeare",
#       "start": 1314,
#       "end": 1334
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.9367560148239136,
#       "word": "Lamia",
#       "start": 1350,
#       "end": 1356
#     }
#   ],
#   "actors": [
#     "Robert De Niro",
#     "Michelle Pfeiffer",
#     "Claire Danes"
#   ],
#   "fixed_aspects": [
#     "script",
#     "acting",
#     "plot"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "Robert De Niro",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Michelle Pfeiffer",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Claire Danes",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "script",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "acting",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "plot",
#       "sentiment": "positive"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: pos_613
# {
#   "id": "pos_613",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "GENRE",
#       "score": 0.5778058767318726,
#       "word": "fantasy",
#       "start": 214,
#       "end": 222
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9854376316070557,
#       "word": "StarDust",
#       "start": 386,
#       "end": 395
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.989562451839447,
#       "word": "Robert De Niro",
#       "start": 601,
#       "end": 616
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.990917444229126,
#       "word": "Michelle Pfeiffer",
#       "start": 712,
#       "end": 730
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9894522428512573,
#       "word": "Claire Danes",
#       "start": 756,
#       "end": 769
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.8781657218933105,
#       "word": "Yvaine",
#       "start": 824,
#       "end": 831
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.9544599652290344,
#       "word": "Captain Shakespeare",
#       "start": 1314,
#       "end": 1334
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.9367560148239136,
#       "word": "Lamia",
#       "start": 1350,
#       "end": 1356
#     }
#   ],
#   "actors": [
#     "Robert De Niro",
#     "Michelle Pfeiffer",
#     "Claire Danes"
#   ],
#   "fixed_aspects": [
#     "script",
#     "acting",
#     "plot"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "Robert De Niro",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Michelle Pfeiffer",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Claire Danes",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "script",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "acting",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "plot",
#       "sentiment": "positive"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: pos_614
# {
#   "id": "pos_614",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9776875972747803,
#       "word": "David Kelly",
#       "start": 1074,
#       "end": 1086
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.897669792175293,
#       "word": "Ben Barnes",
#       "start": 1124,
#       "end": 1135
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.9268803000450134,
#       "word": "Una",
#       "start": 1307,
#       "end": 1311
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.9633826017379761,
#       "word": "Tristan",
#       "start": 1645,
#       "end": 1653
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9694269895553589,
#       "word": "(",
#       "start": 1695,
#       "end": 1697
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9192302823066711,
#       "word": "Charlie Cox",
#       "start": 1697,
#       "end": 1708
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.9038509130477905,
#       "word": "Victoria",
#       "start": 1825,
#       "end": 1834
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9840782880783081,
#       "word": "Sienna Miller",
#       "start": 1845,
#       "end": 1859
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9917073845863342,
#       "word": "Peter O",
#       "start": 2197,
#       "end": 2205
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.8487182259559631,
#       "word": "Toole",
#       "start": 2206,
#       "end": 2211
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.9622582793235779,
#       "word": "Primus",
#       "start": 2327,
#       "end": 2334
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.8926610350608826,
#       "word": "Second",
#       "start": 2335,
#       "end": 2342
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.5172316431999207,
#       "word": "us",
#       "start": 2342,
#       "end": 2344
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.669110119342804,
#       "word": "Sextmus",
#       "start": 2345,
#       "end": 2353
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.7635745406150818,
#       "word": "Septimus",
#       "start": 2358,
#       "end": 2367
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.8173543810844421,
#       "word": "Yvaine",
#       "start": 2627,
#       "end": 2634
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9745201468467712,
#       "word": "(",
#       "start": 2634,
#       "end": 2636
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.966710090637207,
#       "word": "Clare Danes",
#       "start": 2636,
#       "end": 2647
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.9192779064178467,
#       "word": "Lamia",
#       "start": 2798,
#       "end": 2804
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.689642071723938,
#       "word": "(",
#       "start": 2804,
#       "end": 2806
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9244109392166138,
#       "word": "Michelle Pfeiffer",
#       "start": 2806,
#       "end": 2823
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9905063509941101,
#       "word": "\"Pirates of the Caribbean",
#       "start": 3337,
#       "end": 3363
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9886388778686523,
#       "word": "Robert DeNiro",
#       "start": 3537,
#       "end": 3551
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.7886934280395508,
#       "word": "Claire",
#       "start": 3885,
#       "end": 3892
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.8970845341682434,
#       "word": "Jason Flemyng",
#       "start": 3985,
#       "end": 3999
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9851649403572083,
#       "word": "Adam Buston",
#       "start": 4000,
#       "end": 4012
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9923245906829834,
#       "word": "Rupert Everett",
#       "start": 4013,
#       "end": 4028
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9890587329864502,
#       "word": "Mark Strong",
#       "start": 4033,
#       "end": 4045
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.8797305822372437,
#       "word": "\"Blithe Spirit",
#       "start": 4139,
#       "end": 4154
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9543238282203674,
#       "word": "\"High Spirits",
#       "start": 4159,
#       "end": 4173
#     },
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.961194634437561,
#       "word": "Matthew Vaughn",
#       "start": 4193,
#       "end": 4208
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.8658108711242676,
#       "word": "\"Layer Cake",
#       "start": 4251,
#       "end": 4263
#     }
#   ],
#   "actors": [
#     "David Kelly",
#     "(",
#     "Charlie Cox",
#     "Sienna Miller",
#     "Peter O",
#     "Toole",
#     "Clare Danes",
#     "Michelle Pfeiffer",
#     "Robert DeNiro",
#     "Claire",
#     "Jason Flemyng",
#     "Adam Buston",
#     "Rupert Everett",
#     "Mark Strong"
#   ],
#   "fixed_aspects": [
#     "acting",
#     "script"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "David Kelly",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "(",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Charlie Cox",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Sienna Miller",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Peter O",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Toole",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Clare Danes",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Michelle Pfeiffer",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Robert DeNiro",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Claire",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Jason Flemyng",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Adam Buston",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Rupert Everett",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Mark Strong",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "acting",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "script",
#       "sentiment": "positive"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: pos_614
# {
#   "id": "pos_614",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9776875972747803,
#       "word": "David Kelly",
#       "start": 1074,
#       "end": 1086
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.897669792175293,
#       "word": "Ben Barnes",
#       "start": 1124,
#       "end": 1135
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.9268803000450134,
#       "word": "Una",
#       "start": 1307,
#       "end": 1311
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.9633826017379761,
#       "word": "Tristan",
#       "start": 1645,
#       "end": 1653
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9694269895553589,
#       "word": "(",
#       "start": 1695,
#       "end": 1697
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9192302823066711,
#       "word": "Charlie Cox",
#       "start": 1697,
#       "end": 1708
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.9038509130477905,
#       "word": "Victoria",
#       "start": 1825,
#       "end": 1834
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9840782880783081,
#       "word": "Sienna Miller",
#       "start": 1845,
#       "end": 1859
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9917073845863342,
#       "word": "Peter O",
#       "start": 2197,
#       "end": 2205
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.8487182259559631,
#       "word": "Toole",
#       "start": 2206,
#       "end": 2211
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.9622582793235779,
#       "word": "Primus",
#       "start": 2327,
#       "end": 2334
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.8926610350608826,
#       "word": "Second",
#       "start": 2335,
#       "end": 2342
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.5172316431999207,
#       "word": "us",
#       "start": 2342,
#       "end": 2344
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.669110119342804,
#       "word": "Sextmus",
#       "start": 2345,
#       "end": 2353
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.7635745406150818,
#       "word": "Septimus",
#       "start": 2358,
#       "end": 2367
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.8173543810844421,
#       "word": "Yvaine",
#       "start": 2627,
#       "end": 2634
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9745201468467712,
#       "word": "(",
#       "start": 2634,
#       "end": 2636
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.966710090637207,
#       "word": "Clare Danes",
#       "start": 2636,
#       "end": 2647
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.9192779064178467,
#       "word": "Lamia",
#       "start": 2798,
#       "end": 2804
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.689642071723938,
#       "word": "(",
#       "start": 2804,
#       "end": 2806
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9244109392166138,
#       "word": "Michelle Pfeiffer",
#       "start": 2806,
#       "end": 2823
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9905063509941101,
#       "word": "\"Pirates of the Caribbean",
#       "start": 3337,
#       "end": 3363
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9886388778686523,
#       "word": "Robert DeNiro",
#       "start": 3537,
#       "end": 3551
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.7886934280395508,
#       "word": "Claire",
#       "start": 3885,
#       "end": 3892
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.8970845341682434,
#       "word": "Jason Flemyng",
#       "start": 3985,
#       "end": 3999
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9851649403572083,
#       "word": "Adam Buston",
#       "start": 4000,
#       "end": 4012
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9923245906829834,
#       "word": "Rupert Everett",
#       "start": 4013,
#       "end": 4028
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9890587329864502,
#       "word": "Mark Strong",
#       "start": 4033,
#       "end": 4045
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.8797305822372437,
#       "word": "\"Blithe Spirit",
#       "start": 4139,
#       "end": 4154
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9543238282203674,
#       "word": "\"High Spirits",
#       "start": 4159,
#       "end": 4173
#     },
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.961194634437561,
#       "word": "Matthew Vaughn",
#       "start": 4193,
#       "end": 4208
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.8658108711242676,
#       "word": "\"Layer Cake",
#       "start": 4251,
#       "end": 4263
#     }
#   ],
#   "actors": [
#     "David Kelly",
#     "(",
#     "Charlie Cox",
#     "Sienna Miller",
#     "Peter O",
#     "Toole",
#     "Clare Danes",
#     "Michelle Pfeiffer",
#     "Robert DeNiro",
#     "Claire",
#     "Jason Flemyng",
#     "Adam Buston",
#     "Rupert Everett",
#     "Mark Strong"
#   ],
#   "fixed_aspects": [
#     "acting",
#     "script"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "David Kelly",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "(",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Charlie Cox",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Sienna Miller",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Peter O",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Toole",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Clare Danes",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Michelle Pfeiffer",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Robert DeNiro",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Claire",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Jason Flemyng",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Adam Buston",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Rupert Everett",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Mark Strong",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "acting",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "script",
#       "sentiment": "positive"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: pos_615
# {
#   "id": "pos_615",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9546957612037659,
#       "word": "Danes",
#       "start": 106,
#       "end": 112
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9449606537818909,
#       "word": "Deniro",
#       "start": 113,
#       "end": 120
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9581797122955322,
#       "word": "Pfieffer",
#       "start": 124,
#       "end": 133
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.9683400392532349,
#       "word": "Tristan",
#       "start": 194,
#       "end": 202
#     }
#   ],
#   "actors": [
#     "Danes",
#     "Deniro",
#     "Pfieffer"
#   ],
#   "fixed_aspects": [
#     "acting",
#     "ending"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "Danes",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Deniro",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Pfieffer",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "acting",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "ending",
#       "sentiment": "positive"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: pos_615
# {
#   "id": "pos_615",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9546957612037659,
#       "word": "Danes",
#       "start": 106,
#       "end": 112
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9449606537818909,
#       "word": "Deniro",
#       "start": 113,
#       "end": 120
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9581797122955322,
#       "word": "Pfieffer",
#       "start": 124,
#       "end": 133
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.9683400392532349,
#       "word": "Tristan",
#       "start": 194,
#       "end": 202
#     }
#   ],
#   "actors": [
#     "Danes",
#     "Deniro",
#     "Pfieffer"
#   ],
#   "fixed_aspects": [
#     "acting",
#     "ending"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "Danes",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Deniro",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "Pfieffer",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "acting",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "ending",
#       "sentiment": "positive"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: pos_616
# {
#   "id": "pos_616",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "GENRE",
#       "score": 0.4792591333389282,
#       "word": "fantasy",
#       "start": 79,
#       "end": 87
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9490494132041931,
#       "word": "\"",
#       "start": 193,
#       "end": 195
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9150866270065308,
#       "word": "Stardust",
#       "start": 195,
#       "end": 203
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9876835346221924,
#       "word": "Mirrormask",
#       "start": 352,
#       "end": 363
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9742608666419983,
#       "word": "Pan's Labyrinth",
#       "start": 397,
#       "end": 413
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9885468482971191,
#       "word": "The Princess Bride",
#       "start": 450,
#       "end": 469
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.9700886607170105,
#       "word": "Tristan",
#       "start": 793,
#       "end": 801
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.8671314120292664,
#       "word": "Yvaine",
#       "start": 1032,
#       "end": 1039
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.980124831199646,
#       "word": "Robert DeNiro",
#       "start": 1414,
#       "end": 1428
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9466063976287842,
#       "word": "Brazil",
#       "start": 1838,
#       "end": 1845
#     }
#   ],
#   "actors": [
#     "Robert DeNiro"
#   ],
#   "fixed_aspects": [
#     "cinematography",
#     "plot"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "Robert DeNiro",
#       "sentiment": "neutral"
#     },
#     {
#       "aspect": "cinematography",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "plot",
#       "sentiment": "positive"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: pos_616
# {
#   "id": "pos_616",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "GENRE",
#       "score": 0.4792591333389282,
#       "word": "fantasy",
#       "start": 79,
#       "end": 87
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9490494132041931,
#       "word": "\"",
#       "start": 193,
#       "end": 195
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9150866270065308,
#       "word": "Stardust",
#       "start": 195,
#       "end": 203
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9876835346221924,
#       "word": "Mirrormask",
#       "start": 352,
#       "end": 363
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9742608666419983,
#       "word": "Pan's Labyrinth",
#       "start": 397,
#       "end": 413
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9885468482971191,
#       "word": "The Princess Bride",
#       "start": 450,
#       "end": 469
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.9700886607170105,
#       "word": "Tristan",
#       "start": 793,
#       "end": 801
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.8671314120292664,
#       "word": "Yvaine",
#       "start": 1032,
#       "end": 1039
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.980124831199646,
#       "word": "Robert DeNiro",
#       "start": 1414,
#       "end": 1428
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9466063976287842,
#       "word": "Brazil",
#       "start": 1838,
#       "end": 1845
#     }
#   ],
#   "actors": [
#     "Robert DeNiro"
#   ],
#   "fixed_aspects": [
#     "cinematography",
#     "plot"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "Robert DeNiro",
#       "sentiment": "neutral"
#     },
#     {
#       "aspect": "cinematography",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "plot",
#       "sentiment": "positive"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: pos_617
# {
#   "id": "pos_617",
# ...
#       "score": 0.5883663892745972,
#       "word": "slasher",
#       "start": 32,
#       "end": 40
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.8800263404846191,
#       "word": "scarecrow",
#       "start": 468,
#       "end": 478
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.9704378247261047,
#       "word": "Freddy",
#       "start": 567,
#       "end": 574
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.8720681667327881,
#       "word": "Pinhead",
#       "start": 577,
#       "end": 585
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.7758866548538208,
#       "word": "The Scarecrow",
#       "start": 604,
#       "end": 618
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.9675037860870361,
#       "word": "Lester",
#       "start": 887,
#       "end": 894
#     }
#   ],
#   "actors": [],
#   "fixed_aspects": [
#     "acting",
#     "characters",
#     "script"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "acting",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "characters",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "script",
#       "sentiment": "negative"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: neg_618
# {
#   "id": "neg_618",
#   "emotion": "disgust",
#   "ner_results": [
#     {
#       "entity_group": "GENRE",
#       "score": 0.5883663892745972,
#       "word": "slasher",
#       "start": 32,
#       "end": 40
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.8800263404846191,
#       "word": "scarecrow",
#       "start": 468,
#       "end": 478
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.9704378247261047,
#       "word": "Freddy",
#       "start": 567,
#       "end": 574
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.8720681667327881,
#       "word": "Pinhead",
#       "start": 577,
#       "end": 585
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.7758866548538208,
#       "word": "The Scarecrow",
#       "start": 604,
#       "end": 618
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.9675037860870361,
#       "word": "Lester",
#       "start": 887,
#       "end": 894
#     }
#   ],
#   "actors": [],
#   "fixed_aspects": [
#     "acting",
#     "characters",
#     "script"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "acting",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "characters",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "script",
#       "sentiment": "negative"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: neg_619
# {
#   "id": "neg_619",
#   "emotion": "disgust",
#   "ner_results": [],
#   "actors": [],
#   "fixed_aspects": [
#     "acting"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "acting",
#       "sentiment": "negative"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: neg_619
# {
#   "id": "neg_619",
#   "emotion": "disgust",
#   "ner_results": [],
#   "actors": [],
#   "fixed_aspects": [
#     "acting"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "acting",
#       "sentiment": "negative"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: neg_620
# {
#   "id": "neg_620",
#   "emotion": "disgust",
#   "ner_results": [
#     {
#       "entity_group": "MOVIE",
#       "score": 0.8712267875671387,
#       "word": "Scarecreow",
#       "start": 99,
#       "end": 110
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.7272680401802063,
#       "word": "Scarecrow",
#       "start": 122,
#       "end": 132
#     }
#   ],
#   "actors": [],
#   "fixed_aspects": [
#     "plot",
#     "acting",
#     "script",
#     "cinematography"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "plot",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "acting",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "script",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "cinematography",
#       "sentiment": "negative"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: neg_620
# {
#   "id": "neg_620",
#   "emotion": "disgust",
#   "ner_results": [
#     {
#       "entity_group": "MOVIE",
#       "score": 0.8712267875671387,
#       "word": "Scarecreow",
#       "start": 99,
#       "end": 110
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.7272680401802063,
#       "word": "Scarecrow",
#       "start": 122,
#       "end": 132
#     }
#   ],
#   "actors": [],
#   "fixed_aspects": [
#     "plot",
#     "acting",
#     "script",
#     "cinematography"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "plot",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "acting",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "script",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "cinematography",
#       "sentiment": "negative"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: neg_621
# {
#   "id": "neg_621",
#   "emotion": "anger",
#   "ner_results": [
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.44441238045692444,
#       "word": "King",
#       "start": 827,
#       "end": 832
#     }
#   ],
#   "actors": [],
#   "fixed_aspects": [
#     "acting",
#     "plot"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "acting",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "plot",
#       "sentiment": "negative"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: neg_621
# {
#   "id": "neg_621",
#   "emotion": "anger",
#   "ner_results": [
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.44441238045692444,
#       "word": "King",
#       "start": 827,
#       "end": 832
#     }
#   ],
#   "actors": [],
#   "fixed_aspects": [
#     "acting",
#     "plot"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "acting",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "plot",
#       "sentiment": "negative"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: neg_622
# {
#   "id": "neg_622",
#   "emotion": "disgust",
#   "ner_results": [],
#   "actors": [],
#   "fixed_aspects": [
#     "plot",
#     "script"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "plot",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "script",
#       "sentiment": "negative"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: neg_622
# {
#   "id": "neg_622",
#   "emotion": "disgust",
#   "ner_results": [],
#   "actors": [],
#   "fixed_aspects": [
#     "plot",
#     "script"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "plot",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "script",
#       "sentiment": "negative"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: neg_623
# {
#   "id": "neg_623",
#   "emotion": "disgust",
#   "ner_results": [
#     {
#       "entity_group": "ACTOR",
#       "score": 0.46962106227874756,
#       "word": "Tim Young",
#       "start": 104,
#       "end": 113
#     },
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.759813129901886,
#       "word": "Emmanuel Itier",
#       "start": 754,
#       "end": 769
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.3981580138206482,
#       "word": "Du",
#       "start": 857,
#       "end": 860
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.39542096853256226,
#       "word": "Bill Cunningham",
#       "start": 1133,
#       "end": 1149
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9246460199356079,
#       "word": "Jason White",
#       "start": 1151,
#       "end": 1163
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9641428589820862,
#       "word": "The Matrix",
#       "start": 2724,
#       "end": 2735
#     },
#     {
#       "entity_group": "GENRE",
#       "score": 0.4964293837547302,
#       "word": "kung",
#       "start": 2759,
#       "end": 2764
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9614782333374023,
#       "word": "Scarecrows",
#       "start": 4468,
#       "end": 4479
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9862017035484314,
#       "word": "Gene Hackman",
#       "start": 4515,
#       "end": 4528
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9871768355369568,
#       "word": "Al Pacino",
#       "start": 4530,
#       "end": 4540
#     },
#     {
#       "entity_group": "GENRE",
#       "score": 0.5344973802566528,
#       "word": "horror",
#       "start": 4578,
#       "end": 4585
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.949449896812439,
#       "word": "Scarecrow Slayer",
#       "start": 4733,
#       "end": 4750
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9767853617668152,
#       "word": "Scarecrow Gone Wild",
#       "start": 4759,
#       "end": 4779
#     }
#   ],
#   "actors": [
#     "Tim Young",
#     "Bill Cunningham",
#     "Jason White",
#     "Gene Hackman",
#     "Al Pacino"
#   ],
#   "fixed_aspects": [
#     "script",
#     "plot",
#     "characters",
#     "acting",
#     "ending"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "Tim Young",
#       "sentiment": "neutral"
#     },
#     {
#       "aspect": "Bill Cunningham",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "Jason White",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "Gene Hackman",
#       "sentiment": "neutral"
#     },
#     {
#       "aspect": "Al Pacino",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "script",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "plot",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "characters",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "acting",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "ending",
#       "sentiment": "negative"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: neg_623
# {
#   "id": "neg_623",
#   "emotion": "disgust",
#   "ner_results": [
#     {
#       "entity_group": "ACTOR",
#       "score": 0.46962106227874756,
#       "word": "Tim Young",
#       "start": 104,
#       "end": 113
#     },
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.759813129901886,
#       "word": "Emmanuel Itier",
#       "start": 754,
#       "end": 769
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.3981580138206482,
#       "word": "Du",
#       "start": 857,
#       "end": 860
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.39542096853256226,
#       "word": "Bill Cunningham",
#       "start": 1133,
#       "end": 1149
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9246460199356079,
#       "word": "Jason White",
#       "start": 1151,
#       "end": 1163
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9641428589820862,
#       "word": "The Matrix",
#       "start": 2724,
#       "end": 2735
#     },
#     {
#       "entity_group": "GENRE",
#       "score": 0.4964293837547302,
#       "word": "kung",
#       "start": 2759,
#       "end": 2764
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9614782333374023,
#       "word": "Scarecrows",
#       "start": 4468,
#       "end": 4479
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9862017035484314,
#       "word": "Gene Hackman",
#       "start": 4515,
#       "end": 4528
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9871768355369568,
#       "word": "Al Pacino",
#       "start": 4530,
#       "end": 4540
#     },
#     {
#       "entity_group": "GENRE",
#       "score": 0.5344973802566528,
#       "word": "horror",
#       "start": 4578,
#       "end": 4585
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.949449896812439,
#       "word": "Scarecrow Slayer",
#       "start": 4733,
#       "end": 4750
#     },
#     {
#       "entity_group": "MOVIE",
#       "score": 0.9767853617668152,
#       "word": "Scarecrow Gone Wild",
#       "start": 4759,
#       "end": 4779
#     }
#   ],
#   "actors": [
#     "Tim Young",
#     "Bill Cunningham",
#     "Jason White",
#     "Gene Hackman",
#     "Al Pacino"
#   ],
#   "fixed_aspects": [
#     "script",
#     "plot",
#     "characters",
#     "acting",
#     "ending"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "Tim Young",
#       "sentiment": "neutral"
#     },
#     {
#       "aspect": "Bill Cunningham",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "Jason White",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "Gene Hackman",
#       "sentiment": "neutral"
#     },
#     {
#       "aspect": "Al Pacino",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "script",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "plot",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "characters",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "acting",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "ending",
#       "sentiment": "negative"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: neg_624
# {
#   "id": "neg_624",
#   "emotion": "disgust",
#   "ner_results": [
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.918923020362854,
#       "word": "Dario Argento",
#       "start": 134,
#       "end": 148
#     },
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.8938376903533936,
#       "word": "George A",
#       "start": 192,
#       "end": 201
#     },
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.883189857006073,
#       "word": "Romero",
#       "start": 202,
#       "end": 209
#     },
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.7820590138435364,
#       "word": "Tobe Hooper",
#       "start": 213,
#       "end": 225
#     }
#   ],
#   "actors": [],
#   "fixed_aspects": [
#     "acting"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "acting",
#       "sentiment": "negative"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: neg_624
# {
#   "id": "neg_624",
#   "emotion": "disgust",
#   "ner_results": [
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.918923020362854,
#       "word": "Dario Argento",
#       "start": 134,
#       "end": 148
#     },
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.8938376903533936,
#       "word": "George A",
#       "start": 192,
#       "end": 201
#     },
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.883189857006073,
#       "word": "Romero",
#       "start": 202,
#       "end": 209
#     },
#     {
#       "entity_group": "DIRECTOR",
#       "score": 0.7820590138435364,
#       "word": "Tobe Hooper",
#       "start": 213,
#       "end": 225
#     }
#   ],
#   "actors": [],
#   "fixed_aspects": [
#     "acting"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "acting",
#       "sentiment": "negative"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: neg_625
# {
#   "id": "neg_625",
#   "emotion": "disgust",
#   "ner_results": [
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.8900833129882812,
#       "word": "scarecrow",
#       "start": 325,
#       "end": 335
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.9378483295440674,
#       "word": "lest",
#       "start": 689,
#       "end": 694
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.766209065914154,
#       "word": "er",
#       "start": 694,
#       "end": 696
#     }
#   ],
#   "actors": [],
#   "fixed_aspects": [
#     "characters",
#     "acting"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "characters",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "acting",
#       "sentiment": "negative"
#     }
#   ]
# }
# ------------------------------------------------------------
# ID: neg_625
# {
#   "id": "neg_625",
#   "emotion": "disgust",
#   "ner_results": [
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.8900833129882812,
#       "word": "scarecrow",
#       "start": 325,
#       "end": 335
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.9378483295440674,
#       "word": "lest",
#       "start": 689,
#       "end": 694
#     },
#     {
#       "entity_group": "CHARACTER",
#       "score": 0.766209065914154,
#       "word": "er",
#       "start": 694,
#       "end": 696
#     }
#   ],
#   "actors": [],
#   "fixed_aspects": [
#     "characters",
#     "acting"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "characters",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "acting",
#       "sentiment": "negative"
#     }
#   ]
# }
# ------------------------------------------------------------

# %%
with open(OUTPUT_JSON_PATH, "w", encoding="utf-8") as f:
    json.dump(all_outputs_for_json, f, ensure_ascii=False, indent=2)

print(f"\nSaved JSON predictions to: {OUTPUT_JSON_PATH}")
# Out:
# Saved JSON predictions to: ner_absa_predictions.json

# %% [markdown]
# Test With Custom Inpus

# %%
custom_text = """
A Man Called Otto was absolutely amazing! Tom Hanks delivered an outstanding performance,
and the cinematography was breathtaking. However, the ending felt rushed and disappointing.
The music score by Hans Zimmer elevated every scene, and the plot kept me engaged throughout.
"""

custom_aspects = ["plot", "cinematography", "ending", "music"]

print("===== Custom Text Prediction =====\n")
print(f"Text: {custom_text.strip()}\n")

ner_results = ner_pipeline(custom_text)
ner_results = normalize_ner_results(ner_results)

print("Detected Entities (from NER):")
for ent in ner_results:
    print(f"  - {ent['word']} ({ent['entity_group']}): score={ent['score']:.4f}")

actors = extract_actors(ner_results)
print(f"\nDetected Actors: {actors}")

all_aspects = actors + custom_aspects
print(f"All Aspects: {all_aspects}\n")

emotion_label = predict_emotion(custom_text)
print(f"Overall Emotion: {emotion_label}\n")

print("ABSA Results:")
absa_results = []
for aspect in all_aspects:
    sentiment = predict_absa(custom_text, aspect)
    absa_results.append({
        "aspect": aspect,
        "sentiment": sentiment
    })
    print(f"  - {aspect}: {sentiment}")

custom_result = {
    "text": custom_text.strip(),
    "emotion": emotion_label,
    "ner_results": ner_results,
    "actors": actors,
    "custom_aspects": custom_aspects,
    "all_aspects": all_aspects,
    "absa_predictions": absa_results
}

print("\n" + "=" * 60)
print("Complete Result:")
print(json.dumps(custom_result, indent=2, ensure_ascii=False))
# Out:
# ===== Custom Text Prediction =====
#
# Text: A Man Called Otto was absolutely amazing! Tom Hanks delivered an outstanding performance,
# and the cinematography was breathtaking. However, the ending felt rushed and disappointing.
# The music score by Hans Zimmer elevated every scene, and the plot kept me engaged throughout.
#
# Detected Entities (from NER):
#   - A Man Called Otto (MOVIE): score=0.9898
#   - Tom Hanks (ACTOR): score=0.9909
#
# Detected Actors: ['Tom Hanks']
# All Aspects: ['Tom Hanks', 'plot', 'cinematography', 'ending', 'music']
#
# Overall Emotion: joy
#
# ABSA Results:
#   - Tom Hanks: positive
#   - plot: positive
#   - cinematography: positive
#   - ending: negative
#   - music: positive
#
# ============================================================
# Complete Result:
# {
#   "text": "A Man Called Otto was absolutely amazing! Tom Hanks delivered an outstanding performance,\nand the cinematography was breathtaking. However, the ending felt rushed and disappointing.\nThe music score by Hans Zimmer elevated every scene, and the plot kept me engaged throughout.",
#   "emotion": "joy",
#   "ner_results": [
#     {
#       "entity_group": "MOVIE",
#       "score": 0.989806056022644,
#       "word": "A Man Called Otto",
#       "start": 1,
#       "end": 18
#     },
#     {
#       "entity_group": "ACTOR",
#       "score": 0.9908803701400757,
#       "word": "Tom Hanks",
#       "start": 42,
#       "end": 52
#     }
#   ],
#   "actors": [
#     "Tom Hanks"
#   ],
#   "custom_aspects": [
#     "plot",
#     "cinematography",
#     "ending",
#     "music"
#   ],
#   "all_aspects": [
#     "Tom Hanks",
#     "plot",
#     "cinematography",
#     "ending",
#     "music"
#   ],
#   "absa_predictions": [
#     {
#       "aspect": "Tom Hanks",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "plot",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "cinematography",
#       "sentiment": "positive"
#     },
#     {
#       "aspect": "ending",
#       "sentiment": "negative"
#     },
#     {
#       "aspect": "music",
#       "sentiment": "positive"
#     }
#   ]
# }
